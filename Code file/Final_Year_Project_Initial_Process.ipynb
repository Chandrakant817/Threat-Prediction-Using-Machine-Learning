# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.concat(map(pd.read_csv, ['/content/tpot-logs.csv','/content/Untitled discover search(2).csv','/content/Untitled discover search (1).csv','/content/Untitled discover search.csv','/content/Untitled discover search (3).csv','/content/Untitled discover search (4).csv','/content/Untitled discover search (5).csv','/content/Untitled discover search (6).csv']), ignore_index=True)

# %%
df.head(4)
# Out:
#                     @timestamp  @version                   _id  \
# 0  Jan 12, 2022 @ 21:29:05.218         1  G8MDT34BLuMI5c-npjYW
# 1  Jan 12, 2022 @ 21:29:05.000         1  HMMDT34BLuMI5c-npzb9
# 2  Jan 12, 2022 @ 21:29:05.000         1  HcMDT34BLuMI5c-npzb9
# 3  Jan 12, 2022 @ 21:29:05.000         1  HsMDT34BLuMI5c-nqTZp
#
#                 _index _score _type alert.action alert.action.keyword  \
# 0  logstash-2022.01.12      -  _doc            -                    -
# 1  logstash-2022.01.12      -  _doc            -                    -
# 2  logstash-2022.01.12      -  _doc            -                    -
# 3  logstash-2022.01.12      -  _doc            -                    -
#
#   alert.category alert.category.keyword  ... fatt_http.responseVersion  \
# 0              -                      -  ...                       NaN
# 1              -                      -  ...                       NaN
# 2              -                      -  ...                       NaN
# ...

# %%
df.tail()
# Out:
#                         @timestamp  @version                   _id  \
# 36121  Mar 11, 2022 @ 20:25:50.000         1  QL56eX8B3a_Uxxy0l74u
# 36122  Mar 11, 2022 @ 20:25:50.000         1  Qb56eX8B3a_Uxxy0l74u
# 36123  Mar 11, 2022 @ 20:25:49.993         1  Kb56eX8B3a_Uxxy0kr5U
# 36124  Mar 11, 2022 @ 20:25:49.929         1  Jr56eX8B3a_Uxxy0kb63
# 36125  Mar 11, 2022 @ 20:25:49.806         1  KL56eX8B3a_Uxxy0kr5U
#
#                     _index _score _type alert.action alert.action.keyword  \
# 36121  logstash-2022.03.11      -  _doc            -                    -
# 36122  logstash-2022.03.11      -  _doc            -                    -
# 36123  logstash-2022.03.11      -  _doc            -                    -
# 36124  logstash-2022.03.11      -  _doc            -                    -
# 36125  logstash-2022.03.11      -  _doc            -                    -
#
#       alert.category alert.category.keyword  ... fatt_http.responseVersion  \
# ...

# %%
df.shape
# Out:
# (36126, 630)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36126 entries, 0 to 36125
# Columns: 630 entries, @timestamp to headers.accept.keyword
# dtypes: float64(4), int64(1), object(625)
# memory usage: 173.6+ MB

# %%
df.describe().T
# Out:
#                                     count    mean           std     min  \
# @version                          36126.0   1.000  0.000000e+00   1.000
# geoip_ext.continent_code              0.0     NaN           NaN     NaN
# geoip_ext.continent_code.keyword      0.0     NaN           NaN     NaN
# geoip_ext.latitude                36126.0  37.750  0.000000e+00  37.750
# geoip_ext.longitude               36126.0 -97.812  5.400200e-11 -97.812
#
#                                      25%     50%     75%     max
# @version                           1.000   1.000   1.000   1.000
# geoip_ext.continent_code             NaN     NaN     NaN     NaN
# geoip_ext.continent_code.keyword     NaN     NaN     NaN     NaN
# geoip_ext.latitude                37.750  37.750  37.750  37.750
# geoip_ext.longitude              -97.812 -97.812 -97.812 -97.812

# %%
df.isnull().sum()
# Out:
# @timestamp                                 0
# @version                                   0
# _id                                        0
# _index                                     0
# _score                                     0
#                                        ...
# fatt_http.serverHeaderHash.keyword     28468
# fatt_http.serverHeaderOrder            28468
# fatt_http.serverHeaderOrder.keyword    28468
# headers.accept                         32086
# headers.accept.keyword                 32086
# Length: 630, dtype: int64

# %%
df.columns
# Out:
# Index(['@timestamp', '@version', '_id', '_index', '_score', '_type',
#        'alert.action', 'alert.action.keyword', 'alert.category',
#        'alert.category.keyword',
#        ...
#        'fatt_http.responseVersion', 'fatt_http.responseVersion.keyword',
#        'fatt_http.server', 'fatt_http.server.keyword',
#        'fatt_http.serverHeaderHash', 'fatt_http.serverHeaderHash.keyword',
#        'fatt_http.serverHeaderOrder', 'fatt_http.serverHeaderOrder.keyword',
#        'headers.accept', 'headers.accept.keyword'],
#       dtype='object', length=630)

# %%
df.head(1)
# Out:
#                     @timestamp  @version                   _id  \
# 0  Jan 12, 2022 @ 21:29:05.218         1  G8MDT34BLuMI5c-npjYW
#
#                 _index _score _type alert.action alert.action.keyword  \
# 0  logstash-2022.01.12      -  _doc            -                    -
#
#   alert.category alert.category.keyword  ... fatt_http.responseVersion  \
# 0              -                      -  ...                       NaN
#
#   fatt_http.responseVersion.keyword fatt_http.server fatt_http.server.keyword  \
# 0                               NaN              NaN                      NaN
#
#   fatt_http.serverHeaderHash fatt_http.serverHeaderHash.keyword  \
# 0                        NaN                                NaN
#
#   fatt_http.serverHeaderOrder fatt_http.serverHeaderOrder.keyword  \
# 0                         NaN                                 NaN
#
#   headers.accept headers.accept.keyword
# 0            NaN                    NaN
#
# [1 rows x 630 columns]

# %%
pd.set_option("display.max_columns",None)
pd.set_option("display.max_rows",None)

# %%
df.head(2)
# Out:
#                     @timestamp  @version                   _id  \
# 0  Jan 12, 2022 @ 21:29:05.218         1  G8MDT34BLuMI5c-npjYW
# 1  Jan 12, 2022 @ 21:29:05.000         1  HMMDT34BLuMI5c-npzb9
#
#                 _index _score _type alert.action alert.action.keyword  \
# 0  logstash-2022.01.12      -  _doc            -                    -
# 1  logstash-2022.01.12      -  _doc            -                    -
#
#   alert.category alert.category.keyword alert.cve_id alert.cve_id.keyword  \
# 0              -                      -            -                    -
# 1              -                      -            -                    -
#
#   alert.gid alert.metadata.affected_product  \
# 0         -                               -
# 1         -                               -
#
#   alert.metadata.affected_product.keyword alert.metadata.attack_target  \
# 0                                       -                            -
# ...

# %%
df.drop(df.columns[2:57], axis=1, inplace=True)

# %%
df.head(2)
# Out:
#                     @timestamp  @version     dest_ip dest_ip.keyword  \
# 0  Jan 12, 2022 @ 21:29:05.218         1  10.182.0.8      10.182.0.8
# 1  Jan 12, 2022 @ 21:29:05.000         1  10.182.0.8      10.182.0.8
#
#   dest_port dist dist.keyword dns.answers.rdata dns.answers.rdata.keyword  \
# 0     64297    -            -                 -                         -
# 1     14447    -            -                 -                         -
#
#   dns.answers.rrname dns.answers.rrname.keyword dns.answers.rrtype  \
# 0                  -                          -                  -
# 1                  -                          -                  -
#
#   dns.answers.rrtype.keyword dns.answers.ttl dns.authorities.rrname  \
# 0                          -               -                      -
# 1                          -               -                      -
#
#   dns.authorities.rrname.keyword dns.authorities.rrtype  \
# 0                              -                      -
# ...

# %%
df.drop(df.columns[5:51], axis=1, inplace=True)

# %%
df.head(2)
# Out:
#                     @timestamp  @version     dest_ip dest_ip.keyword  \
# 0  Jan 12, 2022 @ 21:29:05.218         1  10.182.0.8      10.182.0.8
# 1  Jan 12, 2022 @ 21:29:05.000         1  10.182.0.8      10.182.0.8
#
#   dest_port event_type event_type.keyword fatt_http.clientHeaderHash  \
# 0     64297        tls                tls                          -
# 1     14447          -                  -                          -
#
#   fatt_http.clientHeaderHash.keyword fatt_http.clientHeaderOrder  \
# 0                                  -                           -
# 1                                  -                           -
#
#   fatt_http.clientHeaderOrder.keyword fatt_http.requestFullURI  \
# 0                                   -                        -
# 1                                   -                        -
#
#   fatt_http.requestFullURI.keyword fatt_http.requestMethod  \
# 0                                -                       -
# ...

# %%
df.drop(df.columns[7:60], axis=1, inplace=True)

# %%
df.head(2)
# Out:
#                     @timestamp  @version     dest_ip dest_ip.keyword  \
# 0  Jan 12, 2022 @ 21:29:05.218         1  10.182.0.8      10.182.0.8
# 1  Jan 12, 2022 @ 21:29:05.000         1  10.182.0.8      10.182.0.8
#
#   dest_port event_type event_type.keyword fatt_rdp.highColorDepth.keyword  \
# 0     64297        tls                tls                               -
# 1     14447          -                  -                               -
#
#   fatt_rdp.keyboardFuncKey fatt_rdp.keyboardFuncKey.keyword  \
# 0                        -                                -
# 1                        -                                -
#
#   fatt_rdp.keyboardLayout fatt_rdp.keyboardLayout.keyword  \
# 0                       -                               -
# 1                       -                               -
#
#   fatt_rdp.keyboardSubtype fatt_rdp.keyboardSubtype.keyword  \
# 0                        -                                -
# ...

# %%
df.drop(df.columns[5:66], axis=1, inplace=True)

# %%
df.head(2)
# Out:
#                     @timestamp  @version     dest_ip dest_ip.keyword  \
# 0  Jan 12, 2022 @ 21:29:05.218         1  10.182.0.8      10.182.0.8
# 1  Jan 12, 2022 @ 21:29:05.000         1  10.182.0.8      10.182.0.8
#
#   dest_port flow.pkts_toclient flow.pkts_toserver flow.start  \
# 0     64297                  -                  -          -
# 1     14447                  -                  -          -
#
#                flow_id ftp.commands.arguments ftp.commands.arguments.keyword  \
# 0  474,482,129,511,519                      -                              -
# 1                    -                      -                              -
#
#   ftp.commands.command ftp.commands.command.keyword  \
# 0                    -                            -
# 1                    -                            -
#
#                      geoip.as_org            geoip.as_org.keyword geoip.asn  \
# 0  Hathway IP Over Cable Internet  Hathway IP Over Cable Internet     17488
# ...

# %%
df.drop(df.columns[5:12], axis=1, inplace=True)

# %%
df.head(3)
# Out:
#                     @timestamp  @version     dest_ip dest_ip.keyword  \
# 0  Jan 12, 2022 @ 21:29:05.218         1  10.182.0.8      10.182.0.8
# 1  Jan 12, 2022 @ 21:29:05.000         1  10.182.0.8      10.182.0.8
# 2  Jan 12, 2022 @ 21:29:05.000         1  10.182.0.8      10.182.0.8
#
#   dest_port ftp.commands.command.keyword                    geoip.as_org  \
# 0     64297                            -  Hathway IP Over Cable Internet
# 1     14447                            -                            MCNC
# 2     14447                            -                            MCNC
#
#              geoip.as_org.keyword geoip.asn geoip.city_name  \
# 0  Hathway IP Over Cable Internet     17488         Gangtok
# 1                            MCNC        81               -
# 2                            MCNC        81               -
#
#   geoip.city_name.keyword geoip.continent_code geoip.continent_code.keyword  \
# ...

# %%
df.drop(df.columns[51:70], axis=1, inplace=True)

# %%
df.head(3)
# Out:
#                     @timestamp  @version     dest_ip dest_ip.keyword  \
# 0  Jan 12, 2022 @ 21:29:05.218         1  10.182.0.8      10.182.0.8
# 1  Jan 12, 2022 @ 21:29:05.000         1  10.182.0.8      10.182.0.8
# 2  Jan 12, 2022 @ 21:29:05.000         1  10.182.0.8      10.182.0.8
#
#   dest_port ftp.commands.command.keyword                    geoip.as_org  \
# 0     64297                            -  Hathway IP Over Cable Internet
# 1     14447                            -                            MCNC
# 2     14447                            -                            MCNC
#
#              geoip.as_org.keyword geoip.asn geoip.city_name  \
# 0  Hathway IP Over Cable Internet     17488         Gangtok
# 1                            MCNC        81               -
# 2                            MCNC        81               -
#
#   geoip.city_name.keyword geoip.continent_code geoip.continent_code.keyword  \
# ...

# %%
df.drop(df.columns[54:75], axis=1, inplace=True)

# %%
df.head(2)
# Out:
#                     @timestamp  @version     dest_ip dest_ip.keyword  \
# 0  Jan 12, 2022 @ 21:29:05.218         1  10.182.0.8      10.182.0.8
# 1  Jan 12, 2022 @ 21:29:05.000         1  10.182.0.8      10.182.0.8
#
#   dest_port ftp.commands.command.keyword                    geoip.as_org  \
# 0     64297                            -  Hathway IP Over Cable Internet
# 1     14447                            -                            MCNC
#
#              geoip.as_org.keyword geoip.asn geoip.city_name  \
# 0  Hathway IP Over Cable Internet     17488         Gangtok
# 1                            MCNC        81               -
#
#   geoip.city_name.keyword geoip.continent_code geoip.continent_code.keyword  \
# 0                 Gangtok                   AS                           AS
# 1                       -                   AS                           AS
#
#   geoip.country_code2 geoip.country_code2.keyword geoip.country_code3  \
# ...

# %%
df.columns[57]
# Out:
# 'protocol.keyword'

# %%
df.drop(df.columns[58:129], axis=1, inplace=True)

# %%
df.head()
# Out:
#                     @timestamp  @version     dest_ip dest_ip.keyword  \
# 0  Jan 12, 2022 @ 21:29:05.218         1  10.182.0.8      10.182.0.8
# 1  Jan 12, 2022 @ 21:29:05.000         1  10.182.0.8      10.182.0.8
# 2  Jan 12, 2022 @ 21:29:05.000         1  10.182.0.8      10.182.0.8
# 3  Jan 12, 2022 @ 21:29:05.000         1  10.182.0.8      10.182.0.8
# 4  Jan 12, 2022 @ 21:29:05.000         1  10.182.0.8      10.182.0.8
#
#   dest_port ftp.commands.command.keyword                    geoip.as_org  \
# 0     64297                            -  Hathway IP Over Cable Internet
# 1     14447                            -                            MCNC
# 2     14447                            -                            MCNC
# 3     14447                            -                            MCNC
# 4     14447                            -                            MCNC
#
#              geoip.as_org.keyword geoip.asn geoip.city_name  \
# ...

# %%
df.drop(df.columns[72:88], axis=1, inplace=True)

# %%
df.head(3)
# Out:
#                     @timestamp  @version     dest_ip dest_ip.keyword  \
# 0  Jan 12, 2022 @ 21:29:05.218         1  10.182.0.8      10.182.0.8
# 1  Jan 12, 2022 @ 21:29:05.000         1  10.182.0.8      10.182.0.8
# 2  Jan 12, 2022 @ 21:29:05.000         1  10.182.0.8      10.182.0.8
#
#   dest_port ftp.commands.command.keyword                    geoip.as_org  \
# 0     64297                            -  Hathway IP Over Cable Internet
# 1     14447                            -                            MCNC
# 2     14447                            -                            MCNC
#
#              geoip.as_org.keyword geoip.asn geoip.city_name  \
# 0  Hathway IP Over Cable Internet     17488         Gangtok
# 1                            MCNC        81               -
# 2                            MCNC        81               -
#
#   geoip.city_name.keyword geoip.continent_code geoip.continent_code.keyword  \
# ...

# %%
df.drop(columns=["ftp.commands.command.keyword"],axis=1,inplace=True)

# %%
df.head()
# Out:
#                     @timestamp  @version     dest_ip dest_ip.keyword  \
# 0  Jan 12, 2022 @ 21:29:05.218         1  10.182.0.8      10.182.0.8
# 1  Jan 12, 2022 @ 21:29:05.000         1  10.182.0.8      10.182.0.8
# 2  Jan 12, 2022 @ 21:29:05.000         1  10.182.0.8      10.182.0.8
# 3  Jan 12, 2022 @ 21:29:05.000         1  10.182.0.8      10.182.0.8
# 4  Jan 12, 2022 @ 21:29:05.000         1  10.182.0.8      10.182.0.8
#
#   dest_port                    geoip.as_org            geoip.as_org.keyword  \
# 0     64297  Hathway IP Over Cable Internet  Hathway IP Over Cable Internet
# 1     14447                            MCNC                            MCNC
# 2     14447                            MCNC                            MCNC
# 3     14447                            MCNC                            MCNC
# 4     14447                            MCNC                            MCNC
#
#   geoip.asn geoip.city_name geoip.city_name.keyword geoip.continent_code  \
# ...

# %%
def dropcol(col):
  df[col]=df.drop(columns=[col],axis=1,inplace=True)

# %%
for i in ["geoip.city_name.keyword","geoip.postal_code.keyword","geoip.region_code.keyword","geoip.region_name.keyword","protocol.keyword","type.keyword","uptime","uptime.keyword"]:
  print(dropcol(i))
# Out:
# None
# None
# None
# None
# None
# None
# None
# None

# %%
df.head(3)
# Out:
#                     @timestamp  @version     dest_ip dest_ip.keyword  \
# 0  Jan 12, 2022 @ 21:29:05.218         1  10.182.0.8      10.182.0.8
# 1  Jan 12, 2022 @ 21:29:05.000         1  10.182.0.8      10.182.0.8
# 2  Jan 12, 2022 @ 21:29:05.000         1  10.182.0.8      10.182.0.8
#
#   dest_port                    geoip.as_org            geoip.as_org.keyword  \
# 0     64297  Hathway IP Over Cable Internet  Hathway IP Over Cable Internet
# 1     14447                            MCNC                            MCNC
# 2     14447                            MCNC                            MCNC
#
#   geoip.asn geoip.city_name geoip.continent_code geoip.continent_code.keyword  \
# 0     17488         Gangtok                   AS                           AS
# 1        81               -                   AS                           AS
# 2        81               -                   AS                           AS
#
# ...

# %%
df.shape
# Out:
# (36126, 280)

# %%
df.columns[67]
# Out:
# 'duration'

# %%
df.drop(df.columns[67:], axis=1, inplace=True)

# %%
df.head(2)
# Out:
#                     @timestamp  @version     dest_ip dest_ip.keyword  \
# 0  Jan 12, 2022 @ 21:29:05.218         1  10.182.0.8      10.182.0.8
# 1  Jan 12, 2022 @ 21:29:05.000         1  10.182.0.8      10.182.0.8
#
#   dest_port                    geoip.as_org            geoip.as_org.keyword  \
# 0     64297  Hathway IP Over Cable Internet  Hathway IP Over Cable Internet
# 1     14447                            MCNC                            MCNC
#
#   geoip.asn geoip.city_name geoip.continent_code geoip.continent_code.keyword  \
# 0     17488         Gangtok                   AS                           AS
# 1        81               -                   AS                           AS
#
#   geoip.country_code2 geoip.country_code2.keyword geoip.country_code3  \
# 0                  IN                          IN                  IN
# 1                  HK                          HK                  HK
#
# ...

# %%
df.columns[44]
# Out:
# 'host'

# %%
df.drop(df.columns[44:49], axis=1, inplace=True)

# %%
df.head(2)
# Out:
#                     @timestamp  @version     dest_ip dest_ip.keyword  \
# 0  Jan 12, 2022 @ 21:29:05.218         1  10.182.0.8      10.182.0.8
# 1  Jan 12, 2022 @ 21:29:05.000         1  10.182.0.8      10.182.0.8
#
#   dest_port                    geoip.as_org            geoip.as_org.keyword  \
# 0     64297  Hathway IP Over Cable Internet  Hathway IP Over Cable Internet
# 1     14447                            MCNC                            MCNC
#
#   geoip.asn geoip.city_name geoip.continent_code geoip.continent_code.keyword  \
# 0     17488         Gangtok                   AS                           AS
# 1        81               -                   AS                           AS
#
#   geoip.country_code2 geoip.country_code2.keyword geoip.country_code3  \
# 0                  IN                          IN                  IN
# 1                  HK                          HK                  HK
#
# ...

# %%
df.drop(df.columns[50:57], axis=1, inplace=True)

# %%
df.head(2)
# Out:
#                     @timestamp  @version     dest_ip dest_ip.keyword  \
# 0  Jan 12, 2022 @ 21:29:05.218         1  10.182.0.8      10.182.0.8
# 1  Jan 12, 2022 @ 21:29:05.000         1  10.182.0.8      10.182.0.8
#
#   dest_port                    geoip.as_org            geoip.as_org.keyword  \
# 0     64297  Hathway IP Over Cable Internet  Hathway IP Over Cable Internet
# 1     14447                            MCNC                            MCNC
#
#   geoip.asn geoip.city_name geoip.continent_code geoip.continent_code.keyword  \
# 0     17488         Gangtok                   AS                           AS
# 1        81               -                   AS                           AS
#
#   geoip.country_code2 geoip.country_code2.keyword geoip.country_code3  \
# 0                  IN                          IN                  IN
# 1                  HK                          HK                  HK
#
# ...

# %%
df["geoip_ext.continent_code.keyword"].value_counts()
# Out:
# Series([], Name: geoip_ext.continent_code.keyword, dtype: int64)

# %%
df.drop(columns=["@version","geoip_ext.continent_code","geoip_ext.continent_code.keyword","geoip_ext.location","geoip.dma_code"],axis=1,inplace=True)

# %%
df.head(5)
# Out:
#                     @timestamp     dest_ip dest_ip.keyword dest_port  \
# 0  Jan 12, 2022 @ 21:29:05.218  10.182.0.8      10.182.0.8     64297
# 1  Jan 12, 2022 @ 21:29:05.000  10.182.0.8      10.182.0.8     14447
# 2  Jan 12, 2022 @ 21:29:05.000  10.182.0.8      10.182.0.8     14447
# 3  Jan 12, 2022 @ 21:29:05.000  10.182.0.8      10.182.0.8     14447
# 4  Jan 12, 2022 @ 21:29:05.000  10.182.0.8      10.182.0.8     14447
#
#                      geoip.as_org            geoip.as_org.keyword geoip.asn  \
# 0  Hathway IP Over Cable Internet  Hathway IP Over Cable Internet     17488
# 1                            MCNC                            MCNC        81
# 2                            MCNC                            MCNC        81
# 3                            MCNC                            MCNC        81
# 4                            MCNC                            MCNC        81
#
#   geoip.city_name geoip.continent_code geoip.continent_code.keyword  \
# ...

# %%
df[["dest_ip","src_ip"]].head()
# Out:
#       dest_ip          src_ip
# 0  10.182.0.8   115.96.77.227
# 1  10.182.0.8  152.32.255.215
# 2  10.182.0.8  152.32.255.215
# 3  10.182.0.8  152.32.255.215
# 4  10.182.0.8  152.32.255.215

# %%
df["geoip.country_name"].value_counts()
# Out:
# United States            9677
# -                        5874
# India                    4285
# United Kingdom           2853
# Vietnam                  2495
# Egypt                    2000
# Japan                    1488
# Russia                   1208
# Germany                  1067
# China                    1061
# Netherlands               744
# Guatemala                 663
# Bulgaria                  480
# Brazil                    333
# Nigeria                   290
# Paraguay                  200
# Pakistan                  190
# Singapore                 154
# Panama                    137
# Hong Kong                  94
# Switzerland                77
# Denmark                    74
# Indonesia                  61
# Seychelles                 60
# Poland                     58
# South Korea                55
# Ukraine                    54
# France                     38
# Belize                     33
# Belarus                    24
# Republic of Lithuania      21
# ...

# %%
plt.figure(figsize=(10,9))
sns.countplot(y=df["geoip.city_name"])

# %%
df1=df["geoip.city_name"].replace("-","Nan").head(5)

# %%
df1.head()
# Out:
# 0    Gangtok
# 1        Nan
# 2        Nan
# 3        Nan
# 4        Nan
# Name: geoip.city_name, dtype: object

# %%
df.head(3)
# Out:
#                     @timestamp     dest_ip dest_ip.keyword dest_port  \
# 0  Jan 12, 2022 @ 21:29:05.218  10.182.0.8      10.182.0.8     64297
# 1  Jan 12, 2022 @ 21:29:05.000  10.182.0.8      10.182.0.8     14447
# 2  Jan 12, 2022 @ 21:29:05.000  10.182.0.8      10.182.0.8     14447
#
#                      geoip.as_org            geoip.as_org.keyword geoip.asn  \
# 0  Hathway IP Over Cable Internet  Hathway IP Over Cable Internet     17488
# 1                            MCNC                            MCNC        81
# 2                            MCNC                            MCNC        81
#
#   geoip.city_name geoip.continent_code geoip.continent_code.keyword  \
# 0         Gangtok                   AS                           AS
# 1               -                   AS                           AS
# 2               -                   AS                           AS
#
#   geoip.country_code2 geoip.country_code2.keyword geoip.country_code3  \
# ...

# %%
for i in ["geoip.continent_code.keyword","geoip.country_code2.keyword","geoip.country_code3.keyword","geoip.country_name.keyword","geoip.location","geoip_ext.as_org.keyword","geoip_ext.country_code2.keyword","geoip_ext.country_code3.keyword","geoip_ext.country_name.keyword","geoip_ext.timezone.keyword","src_ip.keyword"]:
  print(dropcol(i))
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None

# %%
df.head(2)
# Out:
#                     @timestamp     dest_ip dest_ip.keyword dest_port  \
# 0  Jan 12, 2022 @ 21:29:05.218  10.182.0.8      10.182.0.8     64297
# 1  Jan 12, 2022 @ 21:29:05.000  10.182.0.8      10.182.0.8     14447
#
#                      geoip.as_org            geoip.as_org.keyword geoip.asn  \
# 0  Hathway IP Over Cable Internet  Hathway IP Over Cable Internet     17488
# 1                            MCNC                            MCNC        81
#
#   geoip.city_name geoip.continent_code geoip.country_code2  \
# 0         Gangtok                   AS                  IN
# 1               -                   AS                  HK
#
#   geoip.country_code3 geoip.country_name        geoip.ip geoip.latitude  \
# 0                  IN              India   115.96.77.227         27.328
# 1                  HK          Hong Kong  152.32.255.215          22.25
#
#   geoip.longitude geoip.postal_code geoip.region_code geoip.region_name  \
# ...

# %%
df.columns[38]
# Out:
# 'type'

# %%
df.drop(df.columns[39:], axis=1, inplace=True)

# %%
df.head(2)
# Out:
#                     @timestamp     dest_ip dest_ip.keyword dest_port  \
# 0  Jan 12, 2022 @ 21:29:05.218  10.182.0.8      10.182.0.8     64297
# 1  Jan 12, 2022 @ 21:29:05.000  10.182.0.8      10.182.0.8     14447
#
#                      geoip.as_org            geoip.as_org.keyword geoip.asn  \
# 0  Hathway IP Over Cable Internet  Hathway IP Over Cable Internet     17488
# 1                            MCNC                            MCNC        81
#
#   geoip.city_name geoip.continent_code geoip.country_code2  \
# 0         Gangtok                   AS                  IN
# 1               -                   AS                  HK
#
#   geoip.country_code3 geoip.country_name        geoip.ip geoip.latitude  \
# 0                  IN              India   115.96.77.227         27.328
# 1                  HK          Hong Kong  152.32.255.215          22.25
#
#   geoip.longitude geoip.postal_code geoip.region_code geoip.region_name  \
# ...

# %%
df.dropna(subset=["dest_ip.keyword"])

# %%
df.drop(columns=["dest_ip.keyword"],axis=1,inplace=True)

# %%
df.shape

# %%
df.drop(columns=["t-pot_ip_ext.keyword","t-pot_ip_int.keyword","proto.keyword","geoip.as_org.keyword"],axis=1,inplace=True)

# %%
df.head(3)

# %%
df.shape

# %% [markdown]
# # *After Removing Most of the columns i.e Fatures from the Dataset.Now this is our final Dataset. *

# %%
data=df.to_csv('Tpot.csv', index=False)

# %%
Data=pd.read_csv("/content/Tpot.csv")

# %%
Data.head()

# %%
Data.shape
